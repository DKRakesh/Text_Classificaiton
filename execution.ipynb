# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/MyDrive/NLPassignment/
# Out:
# /content/drive/MyDrive/NLPassignment

# %%
cd Question1/
# Out:
# /content/drive/MyDrive/NLPassignment/Question1

# %%
ls
# Out:
# bbc-text.csv  Codes/  execution

# %%
cd Codes/
# Out:
# /content/drive/MyDrive/NLPassignment/Question1/Codes

# %%
ls
# Out:
# get_line.py  main.py  nnmodel.py  preprocess.py  __pycache__/  training.py

# %%
# !python3 main.py
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Code explanation
# Epoch [1/1], Step [100/1780], Loss: 0.0094
# Epoch [1/1], Step [200/1780], Loss: 0.0032
# Epoch [1/1], Step [300/1780], Loss: 0.0000
# Epoch [1/1], Step [400/1780], Loss: 0.0000
# Epoch [1/1], Step [500/1780], Loss: 1.4285
# Epoch [1/1], Step [600/1780], Loss: 1.1506
# Epoch [1/1], Step [700/1780], Loss: 3.2635
# Epoch [1/1], Step [800/1780], Loss: 0.8299
# Epoch [1/1], Step [900/1780], Loss: 0.0000
# Epoch [1/1], Step [1000/1780], Loss: 0.0239
# Epoch [1/1], Step [1100/1780], Loss: 1.1388
# Epoch [1/1], Step [1200/1780], Loss: 0.0083
# Epoch [1/1], Step [1300/1780], Loss: 1.9574
# Epoch [1/1], Step [1400/1780], Loss: 0.0000
# Epoch [1/1], Step [1500/1780], Loss: 0.3918
# Epoch [1/1], Step [1600/1780], Loss: 0.9455
# ...
